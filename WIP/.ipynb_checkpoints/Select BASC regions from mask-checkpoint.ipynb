# %%
# %matplotlib inline

import numpy as np
import matplotlib.pylab as plt
from nilearn.image import resample_to_img
from nilearn.input_data import NiftiLabelsMasker
from nilearn.datasets import load_mni152_brain_mask
from nilearn import datasets
import nibabel as nib
import nibabel as nib 
from nilearn.plotting import find_xyz_cut_coords
from nilearn.image import math_img
from nilearn import datasets
from nilearn.input_data import NiftiLabelsMasker
from sklearn.externals.joblib import Memory
from nilearn import plotting


# Load BASC Atlas
basc = datasets.fetch_atlas_basc_multiscale_2015(version='asym')['scale444']
# Create new atlas with only connected regions
from nilearn.regions import connected_label_regions
basc_regions = connected_label_regions(basc)

# Loas Motor mask (WFU Pick Atlas)

basc_data = basc_regions.get_data()
motor_mask='F:/IRM_Marche/masquesROI/mask_whole.nii'
# Resample 
mask_sh=resample_to_img(motor_mask,basc_regions)
mask_sh=math_img('img>0.2',img=mask_sh)
# Intersept of motor and new basc
m_intersept=math_img('img1*img2',img1=basc_regions,img2=mask_sh)

# Now we have the regions that intersept the mask, but we want to select the full region that are in the mask or 
# overlap with it.

#fetch all possible label values 
basc_motor = m_intersept.get_data()  
labels_motor = np.unique(basc_motor)
# remove the 0. value which correspond to voxels out of ROIs
labels_motor = labels_motor[1:]

# Now we take the region label only if included in the region but not too small compared to its size
labels_motor_final=[]
for i in labels_motor:
    reg_size=(basc_data==i).sum()
    reg_motor_size=(basc_motor==i).sum()
    if (reg_motor_size/reg_size)>0.5:
        labels_motor_final.append(i)
        #print(reg_size,reg_motor_size)
labels_motor_final=np.array(labels_motor_final,dtype=int)
print(len(labels_motor_final))

from nilearn.image import new_img_like
new_img=np.copy(basc_motor)
for k in range(len(labels_motor)):
    if k not in labels_motor_final:
        np.putmask(new_img,new_img==k,0)
basc_motor_img=new_img_like(basc,new_img)
plotting.plot_roi(basc_motor_img,display_mode='z',cut_coords=[-52,-30,8,26,38,50,62])
plotting.plot_roi(mask_sh,display_mode='z',cut_coords=[-52,-30,8,26,38,50,62])
# Out:
# C:\Users\mmenoret\Miniconda2\envs\fmri_3\lib\site-packages\scipy\ndimage\interpolation.py:462: UserWarning: The behaviour of affine_transform with a one-dimensional array supplied for the matrix parameter has changed in scipy 0.18.0.
#   "The behaviour of affine_transform with a one-dimensional "
# 204

# %%
labels_motor_final.tofile('F:/IRM_Marche/masquesROI/reg_whole50_basc524asym.np')

# %%
for i in labels_motor_final:
    i=str(i)
    plotting.plot_roi(math_img('img1=='+i,img1=basc_regions),title=i)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-b79b13bdbae0> in <module>()
#       1 for i in labels_motor_final:
#       2     i=str(i)
# ----> 3     plotting.plot_roi(math_img('img1=='+i,img1=basc_regions),title=i)
#
# C:\Users\mmenoret\Miniconda2\envs\fmri_3\lib\site-packages\nilearn\plotting\img_plotting.py in plot_roi(roi_img, bg_img, cut_coords, output_file, display_mode, figure, axes, title, annotate, draw_cross, black_bg, threshold, alpha, cmap, dim, vmin, vmax, **kwargs)
#     669                                 resampling_interpolation='nearest',
#     670                                 alpha=alpha, cmap=cmap,
# --> 671                                 vmin=vmin, vmax=vmax, **kwargs)
#     672     return display
#     673
#
# C:\Users\mmenoret\Miniconda2\envs\fmri_3\lib\site-packages\nilearn\plotting\img_plotting.py in _plot_img_with_bg(img, bg_img, cut_coords, output_file, display_mode, colorbar, figure, axes, title, threshold, annotate, draw_cross, black_bg, vmin, vmax, bg_vmin, bg_vmax, interpolation, display_factory, cbar_vmin, cbar_vmax, **kwargs)
#     182                             threshold=threshold, interpolation=interpolation,
#     183                             colorbar=colorbar, vmin=vmin, vmax=vmax,
# --> 184                             **kwargs)
#     185
#     186     if annotate:
#
# C:\Users\mmenoret\Miniconda2\envs\fmri_3\lib\site-packages\nilearn\plotting\displays.py in add_overlay(self, img, threshold, colorbar, **kwargs)
#     588         # with plot_stat_map
#     589         kwargs.setdefault('interpolation', 'nearest')
# --> 590         ims = self._map_show(img, type='imshow', threshold=threshold, **kwargs)
#     591
#     592         # `ims` can be empty in some corner cases, look at test_img_plotting.test_outlier_cut_coords.
#
# C:\Users\mmenoret\Miniconda2\envs\fmri_3\lib\site-packages\nilearn\plotting\displays.py in _map_show(self, img, type, resampling_interpolation, threshold, **kwargs)
#     643
#     644         if threshold is not None:
# --> 645             data = _utils.niimg._safe_get_data(img, ensure_finite=True)
#     646             if threshold == 0:
#     647                 data = np.ma.masked_equal(data, 0, copy=False)
#
# C:\Users\mmenoret\Miniconda2\envs\fmri_3\lib\site-packages\nilearn\_utils\niimg.py in _safe_get_data(img, ensure_finite)
#      41     gc.collect()
#      42
# ---> 43     data = img.get_data()
#      44     if ensure_finite:
#      45         non_finite_mask = np.logical_not(np.isfinite(data))
#
# KeyboardInterrupt:
